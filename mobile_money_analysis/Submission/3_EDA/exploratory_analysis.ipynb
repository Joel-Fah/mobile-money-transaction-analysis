# %% [markdown]
# # Exploratory Data Analysis — Mobile Money Transactions
# CSC 3221 — Final Project — Group Joelfah
#
# This notebook reproduces all charts under `visualizations/` and the descriptive statistics / key-insights files.

# %%
import os, pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
sns.set_theme(style='whitegrid')

# %% [markdown]
# ## 1. Load cleaned data and master transactions

# %%
users = pd.read_csv('../2_Data_Cleaning/cleaned_data.csv')
tx    = pd.read_csv('../../output/master_transactions.csv', parse_dates=['Date'])
print(users.shape, tx.shape)
users.head()

# %% [markdown]
# ## 2. Run the full EDA script
# All visualisations are generated by `run_eda.py`.

# %%
# %run run_eda.py

# %% [markdown]
# ## 3. Display generated figures

# %%
from IPython.display import Image, display
for f in sorted(os.listdir('visualizations')):
    display(Image('visualizations/' + f))

# %% [markdown]
# ## 4. Descriptive statistics

# %%
pd.read_csv('descriptive_statistics.csv')

# %% [markdown]
# ## 5. Key insights
# See `key_insights.md`.
